# %% [raw]
# ---
# description: Keep only the tensors the encode graph needs; drop LM and property heads.
# output-file: weights.html
# title: Weights
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## The problem
#
# `model_weights.safetensors` holds **everything** IBM trained: encoder, decoder LM, autoencoder decoder, and a property `net` head. Our MAX graph only implements the **encode** path:
#
# - `encoder.*` (except `encoder.lang_model.*`)
# - `decoder.autoencoder.encoder.*`
#
# Everything else would confuse `load_state_dict` — so we filter.

# %% [markdown]
# ## The adapter
#
# MAX calls this when `WeightsFormat.safetensors` is selected. Input: Hub state dict. Output: `{name: WeightData}` for the graph.

# %%
#| echo: false
#| output: asis
show_doc(convert_safetensor_state_dict)
# Out:
# def convert_safetensor_state_dict(
#     state_dict:Mapping[str, Weights]
# )->dict[str, WeightData]:"""Filter Hub safetensors down to encode-graph weights."""

# %% [markdown]
# A tiny unit test with fake keys — no GPU required:

# %% [markdown]
# ### Checkpoint
#
# *Kept: `encoder.*` + `decoder.autoencoder.encoder.*`. Dropped: LM heads, AE decoder, `net`.*
